# %%
import base64
import requests # type: ignore
import json
import os
import mimetypes

# os.system("cd ../../;php artisan migrate:fresh --seed")
# os.system("mysql --database='shop_point' -e 'DELETE from commands where id > 1; DELETE FROM debts WHERE id>2;DELETE FROM waiting_stocks;DELETE FROM waiting_wallet_operations;DELETE FROM stocks;DELETE FROM refunds;'")
# os.system("mysql --database='shop_point' -e 'ALTER TABLE `commands` auto_increment = 1;ALTER TABLE `debts` auto_increment = 1;ALTER TABLE `waiting_stocks` auto_increment = 1;ALTER TABLE `waiting_wallet_operations` auto_increment = 1;ALTER TABLE `stocks` auto_increment = 1;ALTER TABLE `refunds` auto_increment = 1;'")
# os.system("mysql --database='shop_point' < stocks.sql")
# link_base = "http://credit.cofina.localhost/api/"
link_base = "https://credittg.cofinaonline.com/api/"

WARNING_COLOR = "\033[93m"
RESET_COLOR = "\033[0m"

def image_to_base64_old(image_path):
    with open(image_path, "rb") as image_file:
        base64_string = base64.b64encode(image_file.read()).decode("utf-8")
    return base64_string


def image_to_base64(image_path):
    with open(image_path, "rb") as image_file:
        image_data = image_file.read()
        mime_type, _ = mimetypes.guess_type(image_path)
        base64_string = f"data:{mime_type};base64," + base64.b64encode(
            image_data
        ).decode("utf-8")
    return base64_string


def get(
    path,
    data={},
    link_base=link_base,
    headers_sup={},
):
    headers = {"Content-Type": "application/json", "Accept": "application/json"}
    headers.update(headers_sup)
    response = requests.get(
        link_base + path, data=json.dumps(data), headers=headers, verify=False
    ).json()
    print(f"{WARNING_COLOR}{path}{RESET_COLOR}")
    return response


def post(
    path,
    data={},
    link_base=link_base,
    headers_sup={},
):
    headers = {"Content-Type": "application/json", "Accept": "application/json"}
    headers.update(headers_sup)
    response = requests.post(
        link_base + path, data=json.dumps(data), headers=headers, verify=False
    ).json()
    print(f"{WARNING_COLOR}{path}{RESET_COLOR}")
    return response


def put(
    path,
    data={},
    link_base=link_base,
    headers_sup={},
):
    headers = {"Content-Type": "application/json", "Accept": "application/json"}
    headers.update(headers_sup)
    response = requests.put(
        f"{link_base}{path}", data=json.dumps(data), headers=headers, verify=False
    ).json()
    print(f"{WARNING_COLOR}{path}{RESET_COLOR}")
    return response


response = post(
    "auth/login",
    {"email": "admin@cofinacorp.com", "password": "Coftg@20$*21ù!ad"},
)
admin = response["data"]
print(json.dumps(admin, indent=4))
# Out:
# /var/www/html/Projets/Cofina/CofCredit/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'credittg.cofinaonline.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# auth/login
# {
#     "userToken": "4|LO3CfrwzUmYByQ281Pc2FkUtrvexsCA5g35csUNre4179de9",
#     "user": {
#         "id": 1,
#         "name": "admin",
#         "email": "admin@cofinacorp.com",
#         "full_name": "admin",
#         "profile": "admin",
#         "email_verified_at": null,
#         "si_profile_id": null,
#         "activated": true,
#         "password_change_required": false,
#         "signatory_path": null,
#         "created_at": "2025-02-17T13:11:45.000000Z",
#         "updated_at": "2025-02-17T13:11:45.000000Z",
#         "ability_rules": [
#             {
#                 "action": [
# ...

# %%
cafDataList = [
    {"name": "Abire KPENIFEI KPATCHA", "email": "abire.kpenifei@cofinacorp.com"},
    {"name": "Abra  DOUGAME", "email": "abra.dougame@cofinacorp.com"},
    {"name": "Aimé KETCHAOU", "email": "aime.ketchaou@cofinacorp.com"},
    {"name": "Akossiwa Makafui BADOHOUN", "email": "makafui.badohoun@cofinacorp.com"},
    {"name": "Akouavi AKOSSOU", "email": "akouavi.akossou@cofinacorp.com"},
    {"name": "Akuvi Mawuena AVOGAH-DOGBLE", "email": "akuvi.avogah-dogble@cofinacorp.com"},
    {"name": "Alex Kossivi AGBAVON", "email": "alex.agbavon@cofinacorp.com"},
    {"name": "Amah AYIKOE", "email": "amah.ayikoe@cofinacorp.com"},
    {"name": "Améyo Chimène Edwige  ATTILA", "email": "edwige.attila@cofinacorp.com"},
    {"name": "Anne-Andrée GROISILLIER NGUEMA", "email": "anne-andree.groisillier@cofinacorp.com"},
    {"name": "Assowè MABOUGRE", "email": "assowe.mabougre@cofinacorp.com"},
    {"name": "Ayoko Mireille AMOUZOU", "email": "ayoko.amouzou@cofinacorp.com"},
    {"name": "Baliza  TEKPEZI", "email": "baliza.tekpezi@cofinacorp.com"},
    {"name": "Chimene  AZEGUE", "email": "chimene.azegue@cofinacorp.com"},
    {"name": "Christian  AMEGA", "email": "christian.amega@cofinacorp.com"},
    {"name": "David Martial  SOUSSOUKPO", "email": "david-martial.soussoukpo@cofinacorp.com"},
    {"name": "Diane  ABIASSI", "email": "diane.abiassi@cofinacorp.com"},
    {"name": "Emeline LAWSON-ADJRI", "email": "emeline.lawson-adjri@cofinacorp.com"},
    {"name": "Enyonam AGBLEHOE", "email": "enyonam.agblehoe@cofinacorp.com"},
    {"name": "Eric  MESSANGAN", "email": "eric.messangan@cofinacorp.com"},
    {"name": "Fatima Badoawè TCHA-COROUDOU", "email": "fatima.tcha-coroudou@cofinacorp.com"},
    {"name": "Gafar Tchapo  NABINE", "email": "gafar.nabine@cofinacorp.com"},
    {"name": "Gianni Patrick Attiogbe  KOUDOSSOU", "email": "gianni.koudossou@cofinacorp.com"},
    {"name": "Gnimdo KOMOU", "email": "gnimdo.komou@cofinacorp.com"},
    {"name": "Gnonyarou  WALLA", "email": "gnonyarou.walla@cofinacorp.com"},
    {"name": "Isso Dénis  TACHIDA", "email": "denis.tatchida@cofinacorp.com"},
    {"name": "Joseph AGBI", "email": "joseph.agbi@cofinacorp.com"},
    {"name": "Kadiko Pyalo  SOHOU", "email": "kadiko-pyalo.sohou@cofinacorp.com"},
    {"name": "Koami Edoh MISSISSO", "email": "edoh.mississo@cofinacorp.com"},
    {"name": "Koffi  WOEKPO", "email": "koffi.woekpo@cofinacorp.com"},
    {"name": "Koffivi Amenyo TOLESSI", "email": "koffivi.tolessi@cofinacorp.com"},
    {"name": "Kokou Mawuéna  AMEDEMEGNAH", "email": "mawuena.amedemegnah@cofinacorp.com"},
    {"name": "Komi Dogbéda NOLI", "email": "komi.noli@cofinacorp.com"},
    {"name": "Komi Elom ZAGARAGO", "email": "elom.zagarago@cofinacorp.com"},
    {"name": "Komi Vienyeawu KUNAKEY", "email": "komi.kunakey@cofinacorp.com"},
    {"name": "Komivi Kekeli BOKODJIN", "email": "komivi.bokodjin@cofinacorp.com"},
    {"name": "Komla AGBENYEGA", "email": "komla.agbenyega@cofinacorp.com"},
    {"name": "Komla Nopeli AHONDE", "email": "komla.ahonde@cofinacorp.com"},
    {"name": "Komlan  DADZIE", "email": "komlan.dadzie@cofinacorp.com"},
    {"name": "Komlan Somefa  AHATEFOU", "email": "somefa.ahatefou@cofinacorp.com"},
    {"name": "Komlavi GAKPETO", "email": "komlavi.gakpeto@cofinacorp.com"},
    {"name": "Kosi Mensa DUYIBOE", "email": "kosi-mensa.duyiboe@cofinacorp.com"},
    {"name": "Kossi  AGBLEVON", "email": "kossi.agblevon@cofinacorp.com"},
    {"name": "Kossi Dodji AMEGBEDJI", "email": "dodji.amegbedji@cofinacorp.com"},
    {"name": "Kossi TSATSA", "email": "kossi.tsatsa@cofinacorp.com"},
    {"name": "Kossivi YOKOR", "email": "kossivi.yokor@cofinacorp.com"},
    {"name": "Mawule Kokou  DOGBE", "email": "kokou.dogbe@cofinacorp.com"},
    {"name": "Mouyidine Kayode  TSOUMA", "email": "mouyidine.tsouma@cofinacorp.com"},
    {"name": "Nana Al Chafa BONFOH", "email": "nana-alchafa.bonfoh@cofinacorp.com"},
    {"name": "Nyokpogbe AGBENOWOSI", "email": "nykpogbe.agbenowosi@cofinacorp.com"},
    {"name": "Pierre SOGBALI", "email": "pierre.sogbali@cofinacorp.com"},
    {"name": "Simen Broklyn  MEBA", "email": "simen.meba@cofinacorp.com"},
    {"name": "Yao AGBETOSSOU", "email": "yao.agbetossou@cofinacorp.com"},
    {"name": "Yao Fabrice AMESSE", "email": "fabrice.amesse@cofinacorp.com"},
    {"name": "Yao HOETOWOU", "email": "yao.hoetowou@cofinacorp.com"},
    {"name": "Kossivi Alex AGBAVON", "email": "alex.agbavon@cofinacorp.com"},
	{"name": "Nyokpogbe AGBENOWOSI", "email": "nykpogbe.agbenowosi@cofinacorp.com"},
	{"name": "Komla AGBENYEGA", "email": "komla.agbenyega@cofinacorp.com"},
	{"name": "Yao AGBETOSSOU", "email": "yao.agbetossou@cofinacorp.com"},
	{"name": "Kossivi Joseph AGBI ", "email": "joseph.agbi@cofinacorp.com"},
	{"name": "Afi Enyonam AGBLEHOE", "email": "enyonam.agblehoe@cofinacorp.com"},
	{"name": "Kossi AGBLEVON", "email": "kossi.agblevon@cofinacorp.com"},
	{"name": "Komla Nopeli AHONDE", "email": "komla.ahonde@cofinacorp.com"},
	{"name": "Ablam Samuel AKAKPO ", "email": "samuel.akakpo@cofinacorp.com"},
	{"name": "Akouavi AKOSSOU", "email": "akouavi.akossou@cofinacorp.com"},
	{"name": "Christian AMEGA ", "email": "christian.amega@cofinacorp.com"},
	{"name": "Kossi Dodji AMEGBEDJI", "email": "dodji.amegbedji@cofinacorp.com"},
	{"name": "Ayoko Mireille AMOUZOU", "email": "ayoko.amouzou@cofinacorp.com"},
	{"name": "Sakia Georges ATSOU", "email": "georges.atsou@cofinacorp.com"},
	{"name": "Akuvi AVOGAH-DOGBLE", "email": "akuvi.avogah-dogble@cofinacorp.com"},
	{"name": "Amah AYIKOE ", "email": "amah.ayikoe@cofinacorp.com"},
	{"name": "Chimène AZEGUE", "email": "chimene.azegue@cofinacorp.com"},
	{"name": "Nana Al Chafa BONFOH", "email": "nana-alchafa.bonfoh@cofinacorp.com"},
	{"name": "Gloria Pauline CHODATON", "email": "gloria.chodaton@cofinacorp.com"},
	{"name": "Komlan DADZIE ", "email": "komlan.dadzie@cofinacorp.com"},
	{"name": "Abra DOUGAME ", "email": "abra.dougame@cofinacorp.com"},
	{"name": "Kosi Mensah DUYIBOE ", "email": "kosi-mensa.duyiboe@cofinacorp.com"},
	{"name": "Komlavi Dzigbodi GAKPETO", "email": "komlavi.gakpeto@cofinacorp.com"},
	{"name": "Kouassi Francis GAVISSE ", "email": "francis.gavisse@cofinacorp.com"},
	{"name": "Tamegnon Derrick GBESSO", "email": "derrick.gbesso@cofinacorp.com"},
	{"name": "Anne-Andrée GROISILLIER NGUEMA", "email": "anne-andree.groisillier@cofinacorp.com"},
	{"name": "Yao Amènouglo HOETOWOU", "email": "yao.hoetowou@cofinacorp.com"},
	{"name": "Aime Edem Kodjo HOUNSOU DEGBE ", "email": "aime.hounsou-degbe@cofinacorp.com"},
	{"name": "Essowè KETCHAOU", "email": "aime.ketchaou@cofinacorp.com"},
	{"name": "Gnimdo KOMOU", "email": "gnimdo.komou@cofinacorp.com"},
	{"name": "Gianni Patrick Attiogbe KOUDOSSOU ", "email": "gianni.koudossou@cofinacorp.com"},
	{"name": "Komi Vienyeawu KUNAKEY", "email": "komi.kunakey@cofinacorp.com"},
	{"name": "Koko Eméline LAWSON-ADJRI", "email": "emeline.lawson-adjri@cofinacorp.com"},
	{"name": "Assowè MABOUGRE", "email": "assowe.mabougre@cofinacorp.com"},
	{"name": "Simen Broklyn MEBA ", "email": "simen.meba@cofinacorp.com"},
	{"name": "Tchapo Gafar NABINE ", "email": "gafar.nabine@cofinacorp.com"},
	{"name": "Kossi Mawuli SEMEGLO", "email": "samuel.semeglo@cofinacorp.com"},
	{"name": "Kadiko Pyalo SOHOU", "email": "kadiko-pyalo.sohou@cofinacorp.com"},
	{"name": "David Martial SOUSSOUKPO", "email": "david-martial.soussoukpo@cofinacorp.com"},
	{"name": "Fatima Badoawè TCHA-COROUDOU ", "email": "fatima.tcha-coroudou@cofinacorp.com"},
	{"name": "Baliza Pouwèréou TEKPEZI ", "email": "baliza.tekpezi@cofinacorp.com"},
	{"name": "Gnonyarou WALLA", "email": "gnonyarou.walla@cofinacorp.com"},
	{"name": "Kossivi YOKOR", "email": "kossivi.yokor@cofinacorp.com"},
	{"name": "Abdou Kabirou YOMENOU", "email": "kabirou.yomenou@cofinacorp.com"},
    {"name": "AYICOUE Ayi Ghislain-Kevin", "email": "gislain-kevin.ayicoue@cofinacorp.com"},
	{"name": "AYIVI Ayité Wisdom", "email": "wisdom.ayivi@cofinacorp.com"},
	{"name": "KOUDJINO Kokou Samuel", "email": "samuel.koudjino@cofinacorp.com"},
	{"name": "APETOR Anne-Marie", "email": "anna.apetor@gmail.com"},
	{"name": "MISSISSO Koami Edoh", "email": "edoh.mississo@cofinacorp.com"},
	{"name": "TSATSA Kossi", "email": "kossi.tsatsa@cofinacorp.com"},
	{"name": "AGBETOGON Afi Blessing", "email": "blessing.agbetogon@cofinacorp.com"},
]
for data in cafDataList:
    response = post(
        "user",
        {
            "name": data["name"],
            "full_name": data["name"],
            "email": data["email"],
            "profile": "caf",
            "activated": 1,
            "password": "P@sse123",
            "password_change_required": 1,
        },
        headers_sup={"Authorization": f"Bearer {admin['userToken']}"},
    )
    print(f"{data['email']}: {response['status']}")
# Out:
# /var/www/html/Projets/Cofina/CofCredit/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'credittg.cofinaonline.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# user
# abire.kpenifei@cofinacorp.com: 201
# /var/www/html/Projets/Cofina/CofCredit/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'credittg.cofinaonline.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# user
# abra.dougame@cofinacorp.com: 201
# ...

# %%
analystDataList = [
	{"name": "Prudence AYENA", "email": "prudence.ayena@cofinacorp.com"},
	{"name": "Ibrahim TAMBOURA", "email": "ibrahim.tamboura@cofinacorp.com"},
	{"name": "Ovidio De SOUZA", "email": "ovidio.de-souza@cofinacorp.com"},
	{"name": "Sandra AKAKPO-DJAKPATA", "email": "sandra.akakpo@cofinacorp.com"},
	{"name": "Justin E. A.  AMAKOUE", "email": "justin.amakoue@cofinacorp.com"},
	{"name": "Josias EKOUE AZIABA", "email": "josias.aziaba@cofinacorp.com"},
	{"name": "Ama NUTSU", "email": "ama.nutsu@cofinacorp.com"},
	{"name": "Amah Venunye HUNLEDE", "email": "josias.hunlede@cofinacorp.com"}
]
for data in analystDataList:
    response = post(
        "user",
        {
            "name": data["name"],
            "full_name": data["name"],
            "email": data["email"],
            "profile": "credit_analyst",
            "activated": 1,
            "password": "P@sse123",
            "password_change_required": 1,
        },
        headers_sup={"Authorization": f"Bearer {admin['userToken']}"},
    )
    print(f"{data['email']}: {response['status']}")
# Out:
# /var/www/html/Projets/Cofina/CofCredit/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'credittg.cofinaonline.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# user
# prudence.ayena@cofinacorp.com: 201
# /var/www/html/Projets/Cofina/CofCredit/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'credittg.cofinaonline.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# user
# ibrahim.tamboura@cofinacorp.com: 201
# ...

# %%
creditAdminDataListOne = [
	{"name": "Komlan A. Espoir AYEWOUTSE", "email": "espoir.ayewoutse@cofinacorp.com"},
	{"name": "Akuété Pierre DAVON", "email": "pierre.davon@cofinacorp.com"},
]
for data in creditAdminDataListOne:
    response = post(
        "user",
        {
            "name": data["name"],
            "full_name": data["name"],
            "email": data["email"],
            "profile": "credit_admin",
            "activated": 1,
            "password": "P@sse123",
            "password_change_required": 1,
        },
        headers_sup={"Authorization": f"Bearer {admin['userToken']}"},
    )
    print(f"{data['email']}: {response['status']}")
# Out:
# /var/www/html/Projets/Cofina/CofCredit/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'credittg.cofinaonline.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# user
# espoir.ayewoutse@cofinacorp.com: 201
# /var/www/html/Projets/Cofina/CofCredit/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'credittg.cofinaonline.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# user
# pierre.davon@cofinacorp.com: 201

# %%
otherDataListOne = [
	{"name": "Koffi Djramedo GAMADO", "email": "gamligocharles@gmail.com", "profile": "head_credit"},
	{"name": "Mireille MESSANGAN", "email": "gamligocharles2@gmail.com", "profile": "legal"},
]
for data in otherDataListOne:
	response = post(
		"user",
		{
			"name": data["name"],
			"full_name": data["name"],
			"email": data["email"],
			"profile": data["profile"],
			"activated": 1,
			"password": "P@sse123",
			"password_change_required": 1,
		},
		headers_sup={"Authorization": f"Bearer {admin['userToken']}"},
	)
	print(f"{data['email']}: {response['status']}")
# Out:
# /var/www/html/Projets/Cofina/CofCredit/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'credittg.cofinaonline.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# user
# gamligocharles@gmail.com: 201
# /var/www/html/Projets/Cofina/CofCredit/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'credittg.cofinaonline.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# user
# gamligocharles2@gmail.com: 201
